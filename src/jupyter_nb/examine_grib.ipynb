# %%
import os
import xarray as xr

def _print_header(title):
    print("\n" + title)
    print("=" * len(title))

# %%
#grib_path = "/Volumes/Seagate/_datasets/weather-dataset/ERA5-hourly-data/hourly/571364b8d89c70bc4dd467ffb17badcd.grib"
grib_path = "/Volumes/Seagate/_datasets/weather-dataset/ERA5-hourly-data/hourly/571364b8d89c70bc4dd467ffb17badcd.grib"

# %%
if not os.path.isfile(grib_path):
    print(f"File does not exist: {grib_path}")

# %%
print(f"Examining GRIB file: {grib_path}")
print(f"File size: {os.path.getsize(grib_path) / (1024*1024):.2f} MB")
# Out:
# Examining GRIB file: /Volumes/Seagate/_datasets/weather-dataset/ERA5-hourly-data/hourly/571364b8d89c70bc4dd467ffb17badcd.grib
# File size: 5.97 MB

# %%
_print_header("cfgrib/xarray summary")
# Out:
# cfgrib/xarray summary
# =====================

# %%
ds = xr.open_dataset(grib_path, engine='cfgrib')

# %%
print(f"Dimensions: {dict(ds.sizes)}")
# Out:
# Dimensions: {'time': 6791, 'latitude': 5, 'longitude': 5}

# %%
print(f"Coordinates: {list(ds.coords.keys())}")
# Out:
# Coordinates: ['number', 'time', 'step', 'isobaricInhPa', 'latitude', 'longitude', 'valid_time']

# %%
ars_list = list(ds.data_vars.keys())
print(f"Variables: {ars_list}")
# Out:
# Variables: ['cc', 'r', 'q', 't', 'u', 'v']

# %%
for var_name in ars_list:
    da = ds[var_name]
    print(f"Variable '{var_name}': shape={da.shape} dims={da.dims}")
    print(f"  {attr}: {da.attrs['long_name']}")
# Out:
# Variable 'cc': shape=(6791, 5, 5) dims=('time', 'latitude', 'longitude')
#   standard_name: Fraction of cloud cover
# Variable 'r': shape=(6791, 5, 5) dims=('time', 'latitude', 'longitude')
#   standard_name: Relative humidity
# Variable 'q': shape=(6791, 5, 5) dims=('time', 'latitude', 'longitude')
#   standard_name: Specific humidity
# Variable 't': shape=(6791, 5, 5) dims=('time', 'latitude', 'longitude')
#   standard_name: Temperature
# Variable 'u': shape=(6791, 5, 5) dims=('time', 'latitude', 'longitude')
#   standard_name: U component of wind
# Variable 'v': shape=(6791, 5, 5) dims=('time', 'latitude', 'longitude')
#   standard_name: V component of wind

# %%
ds['cc'].attrs['']
# Out:
# <xarray.DataArray 'cc' (time: 6791, latitude: 5, longitude: 5)> Size: 679kB
# [169775 values with dtype=float32]
# Coordinates:
#   * time           (time) datetime64[ns] 54kB 2025-01-01 ... 2025-10-10T22:00:00
#   * latitude       (latitude) float64 40B 19.0 18.75 18.5 18.25 18.0
#   * longitude      (longitude) float64 40B 99.0 99.25 99.5 99.75 100.0
#     number         int64 8B ...
#     step           timedelta64[ns] 8B ...
#     isobaricInhPa  float64 8B ...
#     valid_time     (time) datetime64[ns] 54kB ...
# Attributes: (12/31)
#     GRIB_paramId:                             248
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      25
#     GRIB_typeOfLevel:                         isobaricInhPa
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           cc
#     GRIB_totalNumber:                         0
#     GRIB_units:                               (0 - 1)
#     long_name:                                Fraction of cloud cover
#     units:                                    (0 - 1)
#     standard_name:                            unknown
