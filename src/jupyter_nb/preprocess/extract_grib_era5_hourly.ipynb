# %%
import platform
import xarray as xr
import pandas as pd
import numpy as np
import os
import glob

# %%
netcdf_dir = 'D:\\_datasets\\weather-dataset\\ERA5-hourly-data\\hourly'

# %%
netcdf_pattern = os.path.join(netcdf_dir, "*.grib")
netcdf_files = glob.glob(netcdf_pattern)
print(f"Found {len(netcdf_files)} GRIB files")
# Out:
# Found 7 GRIB files

# %%
all_files = []
for netcdf_file in netcdf_files:
    all_files.append(netcdf_file)
print(all_files[0])
print(all_files[1])
# Out:
# D:\_datasets\weather-dataset\ERA5-hourly-data\hourly\5a732b807ec056db47aace313c25a9ac.grib
# D:\_datasets\weather-dataset\ERA5-hourly-data\hourly\6f0bf495db8bc6e8ec8220c609c4cc6b.grib

# %%
backend_kwargs = {'indexpath': ''}
ds = xr.open_dataset(all_files[0], engine='cfgrib', backend_kwargs=backend_kwargs)

# %%
print("\n=== Grib File Information ===")
print(f"Dimensions: {dict(ds.sizes)}")
print(f"Coordinates: {list(ds.coords.keys())}")
# Out:
# === Grib File Information ===
# Dimensions: {'time': 8784, 'latitude': 5, 'longitude': 5}
# Coordinates: ['number', 'time', 'step', 'isobaricInhPa', 'latitude', 'longitude', 'valid_time']

# %%
vars_list = list(ds.data_vars.keys())
print(f"Dataset variables: {vars_list}")
# Out:
# Dataset variables: ['cc', 'r', 'q', 't', 'u', 'v']

# %%
# Show details for up to first 5 variables
for var_name in vars_list:
    da = ds[var_name]
    print(f"  Variable '{var_name}': shape={da.shape} dims={da.dims}")
# Out:
#   Variable 'cc': shape=(8784, 5, 5) dims=('time', 'latitude', 'longitude')
#   Variable 'r': shape=(8784, 5, 5) dims=('time', 'latitude', 'longitude')
#   Variable 'q': shape=(8784, 5, 5) dims=('time', 'latitude', 'longitude')
#   Variable 't': shape=(8784, 5, 5) dims=('time', 'latitude', 'longitude')
#   Variable 'u': shape=(8784, 5, 5) dims=('time', 'latitude', 'longitude')
#   Variable 'v': shape=(8784, 5, 5) dims=('time', 'latitude', 'longitude')

# %%
# Show details variables
for var_name in vars_list:
    da = ds[var_name]
    print(f"  Variable '{var_name}': shape={da.shape} dims={da.dims}")
    for attr in da.attrs:
        print(f"    {attr}: {da.attrs[attr]}")
# Out:
#   Variable 'cc': shape=(8784, 5, 5) dims=('time', 'latitude', 'longitude')
#     GRIB_paramId: 248
#     GRIB_dataType: an
#     GRIB_numberOfPoints: 25
#     GRIB_typeOfLevel: isobaricInhPa
#     GRIB_stepUnits: 1
#     GRIB_stepType: instant
#     GRIB_gridType: regular_ll
#     GRIB_uvRelativeToGrid: 0
#     GRIB_NV: 0
#     GRIB_Nx: 5
#     GRIB_Ny: 5
#     GRIB_cfName: unknown
#     GRIB_cfVarName: cc
#     GRIB_gridDefinitionDescription: Latitude/Longitude Grid
#     GRIB_iDirectionIncrementInDegrees: 0.25
#     GRIB_iScansNegatively: 0
#     GRIB_jDirectionIncrementInDegrees: 0.25
#     GRIB_jPointsAreConsecutive: 0
#     GRIB_jScansPositively: 0
#     GRIB_latitudeOfFirstGridPointInDegrees: 19.0
#     GRIB_latitudeOfLastGridPointInDegrees: 18.0
#     GRIB_longitudeOfFirstGridPointInDegrees: 99.0
#     GRIB_longitudeOfLastGridPointInDegrees: 100.0
#     GRIB_missingValue: 3.4028234663852886e+38
#     GRIB_name: Fraction of cloud cover
#     GRIB_shortName: cc
#     GRIB_totalNumber: 0
#     GRIB_units: (0 - 1)
#     long_name: Fraction of cloud cover
#     units: (0 - 1)
#     standard_name: unknown
#   Variable 'r': shape=(8784, 5, 5) dims=('time', 'latitude', 'longitude')
#     GRIB_paramId: 157
#     GRIB_dataType: an
#     GRIB_numberOfPoints: 25
#     GRIB_typeOfLevel: isobaricInhPa
#     GRIB_stepUnits: 1
#     GRIB_stepType: instant
#     GRIB_gridType: regular_ll
#     GRIB_uvRelativeToGrid: 0
#     GRIB_NV: 0
#     GRIB_Nx: 5
#     GRIB_Ny: 5
#     GRIB_cfName: relative_humidity
#     GRIB_cfVarName: r
#     GRIB_gridDefinitionDescription: Latitude/Longitude Grid
#     GRIB_iDirectionIncrementInDegrees: 0.25
#     GRIB_iScansNegatively: 0
#     GRIB_jDirectionIncrementInDegrees: 0.25
#     GRIB_jPointsAreConsecutive: 0
#     GRIB_jScansPositively: 0
#     GRIB_latitudeOfFirstGridPointInDegrees: 19.0
#     GRIB_latitudeOfLastGridPointInDegrees: 18.0
#     GRIB_longitudeOfFirstGridPointInDegrees: 99.0
#     GRIB_longitudeOfLastGridPointInDegrees: 100.0
#     GRIB_missingValue: 3.4028234663852886e+38
#     GRIB_name: Relative humidity
#     GRIB_shortName: r
#     GRIB_totalNumber: 0
#     GRIB_units: %
#     long_name: Relative humidity
#     units: %
#     standard_name: relative_humidity
#   Variable 'q': shape=(8784, 5, 5) dims=('time', 'latitude', 'longitude')
#     GRIB_paramId: 133
#     GRIB_dataType: an
#     GRIB_numberOfPoints: 25
#     GRIB_typeOfLevel: isobaricInhPa
#     GRIB_stepUnits: 1
#     GRIB_stepType: instant
#     GRIB_gridType: regular_ll
#     GRIB_uvRelativeToGrid: 0
#     GRIB_NV: 0
#     GRIB_Nx: 5
#     GRIB_Ny: 5
#     GRIB_cfName: specific_humidity
#     GRIB_cfVarName: q
#     GRIB_gridDefinitionDescription: Latitude/Longitude Grid
#     GRIB_iDirectionIncrementInDegrees: 0.25
#     GRIB_iScansNegatively: 0
#     GRIB_jDirectionIncrementInDegrees: 0.25
#     GRIB_jPointsAreConsecutive: 0
#     GRIB_jScansPositively: 0
#     GRIB_latitudeOfFirstGridPointInDegrees: 19.0
#     GRIB_latitudeOfLastGridPointInDegrees: 18.0
#     GRIB_longitudeOfFirstGridPointInDegrees: 99.0
#     GRIB_longitudeOfLastGridPointInDegrees: 100.0
#     GRIB_missingValue: 3.4028234663852886e+38
#     GRIB_name: Specific humidity
#     GRIB_shortName: q
#     GRIB_totalNumber: 0
#     GRIB_units: kg kg**-1
#     long_name: Specific humidity
#     units: kg kg**-1
#     standard_name: specific_humidity
#   Variable 't': shape=(8784, 5, 5) dims=('time', 'latitude', 'longitude')
#     GRIB_paramId: 130
#     GRIB_dataType: an
#     GRIB_numberOfPoints: 25
#     GRIB_typeOfLevel: isobaricInhPa
#     GRIB_stepUnits: 1
#     GRIB_stepType: instant
#     GRIB_gridType: regular_ll
#     GRIB_uvRelativeToGrid: 0
#     GRIB_NV: 0
#     GRIB_Nx: 5
#     GRIB_Ny: 5
#     GRIB_cfName: air_temperature
#     GRIB_cfVarName: t
#     GRIB_gridDefinitionDescription: Latitude/Longitude Grid
#     GRIB_iDirectionIncrementInDegrees: 0.25
#     GRIB_iScansNegatively: 0
#     GRIB_jDirectionIncrementInDegrees: 0.25
#     GRIB_jPointsAreConsecutive: 0
#     GRIB_jScansPositively: 0
#     GRIB_latitudeOfFirstGridPointInDegrees: 19.0
#     GRIB_latitudeOfLastGridPointInDegrees: 18.0
#     GRIB_longitudeOfFirstGridPointInDegrees: 99.0
#     GRIB_longitudeOfLastGridPointInDegrees: 100.0
#     GRIB_missingValue: 3.4028234663852886e+38
#     GRIB_name: Temperature
#     GRIB_shortName: t
#     GRIB_totalNumber: 0
#     GRIB_units: K
#     long_name: Temperature
#     units: K
#     standard_name: air_temperature
#   Variable 'u': shape=(8784, 5, 5) dims=('time', 'latitude', 'longitude')
#     GRIB_paramId: 131
#     GRIB_dataType: an
#     GRIB_numberOfPoints: 25
#     GRIB_typeOfLevel: isobaricInhPa
#     GRIB_stepUnits: 1
#     GRIB_stepType: instant
#     GRIB_gridType: regular_ll
#     GRIB_uvRelativeToGrid: 0
#     GRIB_NV: 0
#     GRIB_Nx: 5
#     GRIB_Ny: 5
#     GRIB_cfName: eastward_wind
#     GRIB_cfVarName: u
#     GRIB_gridDefinitionDescription: Latitude/Longitude Grid
#     GRIB_iDirectionIncrementInDegrees: 0.25
#     GRIB_iScansNegatively: 0
#     GRIB_jDirectionIncrementInDegrees: 0.25
#     GRIB_jPointsAreConsecutive: 0
#     GRIB_jScansPositively: 0
#     GRIB_latitudeOfFirstGridPointInDegrees: 19.0
#     GRIB_latitudeOfLastGridPointInDegrees: 18.0
#     GRIB_longitudeOfFirstGridPointInDegrees: 99.0
#     GRIB_longitudeOfLastGridPointInDegrees: 100.0
#     GRIB_missingValue: 3.4028234663852886e+38
#     GRIB_name: U component of wind
#     GRIB_shortName: u
#     GRIB_totalNumber: 0
#     GRIB_units: m s**-1
#     long_name: U component of wind
#     units: m s**-1
#     standard_name: eastward_wind
#   Variable 'v': shape=(8784, 5, 5) dims=('time', 'latitude', 'longitude')
#     GRIB_paramId: 132
#     GRIB_dataType: an
#     GRIB_numberOfPoints: 25
#     GRIB_typeOfLevel: isobaricInhPa
#     GRIB_stepUnits: 1
#     GRIB_stepType: instant
#     GRIB_gridType: regular_ll
#     GRIB_uvRelativeToGrid: 0
#     GRIB_NV: 0
#     GRIB_Nx: 5
#     GRIB_Ny: 5
#     GRIB_cfName: northward_wind
#     GRIB_cfVarName: v
#     GRIB_gridDefinitionDescription: Latitude/Longitude Grid
#     GRIB_iDirectionIncrementInDegrees: 0.25
#     GRIB_iScansNegatively: 0
#     GRIB_jDirectionIncrementInDegrees: 0.25
#     GRIB_jPointsAreConsecutive: 0
#     GRIB_jScansPositively: 0
#     GRIB_latitudeOfFirstGridPointInDegrees: 19.0
#     GRIB_latitudeOfLastGridPointInDegrees: 18.0
#     GRIB_longitudeOfFirstGridPointInDegrees: 99.0
#     GRIB_longitudeOfLastGridPointInDegrees: 100.0
#     GRIB_missingValue: 3.4028234663852886e+38
#     GRIB_name: V component of wind
#     GRIB_shortName: v
#     GRIB_totalNumber: 0
#     GRIB_units: m s**-1
#     long_name: V component of wind
#     units: m s**-1
#     standard_name: northward_wind
